# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.sql import Window

# Create SparkSession
spark = (SparkSession.builder
                    .appName('PySparkSyntax')
                    .getOrCreate()
        )

# Define the schema for a DataFrame
schema = StructType([
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("city", StringType(), True)
])


# Create a DataFrame using the schema
data = [("Alice", 25, "New York"), ("Bob", 30, "San Francisco"), ("Charlie", 35, "Chicago")]
df = spark.createDataFrame(data, schema)

spark.sparkContext.setLogLevel("WARN") # INFO WARN ERROR DEBUG ALL

# Show the DataFrame
df.show()
# Out:
# +-------+---+-------------+
# |   name|age|         city|
# +-------+---+-------------+
# |  Alice| 25|     New York|
# |    Bob| 30|San Francisco|
# |Charlie| 35|      Chicago|
# +-------+---+-------------+

# %%
df.columns
# Out:
# ['name', 'age', 'city']

# %%
# Creating a new column called 'new_age'
df = df.withColumn('new_age', (F.col('age') + 5).cast('int'))
df.toPandas()
# Out:
#       name  age           city  new_age
# 0    Alice   25       New York       30
# 1      Bob   30  San Francisco       35
# 2  Charlie   35        Chicago       40

# %%
# Replacing a existing new column called 'new_age' with new values
df = df.withColumn('new_age', df.new_age + 2)
df.toPandas()
# Out:
#       name  age           city  new_age
# 0    Alice   25       New York       32
# 1      Bob   30  San Francisco       37
# 2  Charlie   35        Chicago       42

# %%
df = df.withColumn('constant', F.lit('TableA'))
df.toPandas()
# Out:
#       name  age           city  new_age constant
# 0    Alice   25       New York       32   TableA
# 1      Bob   30  San Francisco       37   TableA
# 2  Charlie   35        Chicago       42   TableA

# %%
df = df.withColumnRenamed('new_age', 'new_age2')
df.toPandas()
# Out:
#       name  age           city  new_age2 constant
# 0    Alice   25       New York        32   TableA
# 1      Bob   30  San Francisco        37   TableA
# 2  Charlie   35        Chicago        42   TableA

# %%
df = df.withColumnRenamed('new_age3', 'new_age4')
df.toPandas()
# Out:
#       name  age           city  new_age2 constant
# 0    Alice   25       New York        32   TableA
# 1      Bob   30  San Francisco        37   TableA
# 2  Charlie   35        Chicago        42   TableA

# %%
df = df.select(F.col('name').alias('FirstName')
                ,F.col('age')
                ,F.col('city')
              )

df.toPandas()
# Out:
#   FirstName  age           city
# 0     Alice   25       New York
# 1       Bob   30  San Francisco
# 2   Charlie   35        Chicago

# %%
df = df.drop('city')
df.toPandas()
# Out:
#   FirstName  age
# 0     Alice   25
# 1       Bob   30
# 2   Charlie   35

# %%
df = df.drop('new_age99')
df.toPandas()
# Out:
#   FirstName  age
# 0     Alice   25
# 1       Bob   30
# 2   Charlie   35

# %%
df = df.select('FirstName', 'age')

df.toPandas()
# Out:
#   FirstName  age
# 0     Alice   25
# 1       Bob   30
# 2   Charlie   35

# %%
df_select = df.selectExpr('FirstName as Name', 'age as Age', 'age*2 as DoubleAge')
df_select.toPandas()
# Out:
#       Name  Age  DoubleAge
# 0    Alice   25         50
# 1      Bob   30         60
# 2  Charlie   35         70

# %%
spark.stop()
