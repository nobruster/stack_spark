# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.sql import Window

# Create SparkSession
spark = (SparkSession.builder
                    .appName('PySparkSyntax')
                    .getOrCreate()
        )

# Define the schema for a DataFrame
schema = StructType([
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("city", StringType(), True)
])


# Create a DataFrame using the schema
data = [("Alice", 25, "New York")
        , ("Bob", 30, "San Francisco")
        , ("Bob", 12, "Las Vegas")
        , ("Charlie", 35, "Chicago")
        , ("Charlie", 35, "Chicago")]
df = spark.createDataFrame(data, schema)

# Show the DataFrame
df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/26 21:31:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/26 21:31:15 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/02/26 21:31:15 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 26/02/26 21:31:15 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# +-------+---+-------------+
# |   name|age|         city|
# +-------+---+-------------+
# |  Alice| 25|     New York|
# |    Bob| 30|San Francisco|
# |    Bob| 12|    Las Vegas|
# |Charlie| 35|      Chicago|
# |Charlie| 35|      Chicago|
# +-------+---+-------------+

# %%
df.show()
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# +-------+---+-------------+
# |   name|age|         city|
# +-------+---+-------------+
# |  Alice| 25|     New York|
# |    Bob| 30|San Francisco|
# |    Bob| 12|    Las Vegas|
# |Charlie| 35|      Chicago|
# |Charlie| 35|      Chicago|
# +-------+---+-------------+

# %%
df.show(3)
# Out:
# +-----+---+-------------+
# | name|age|         city|
# +-----+---+-------------+
# |Alice| 25|     New York|
# |  Bob| 30|San Francisco|
# |  Bob| 12|    Las Vegas|
# +-----+---+-------------+
# only showing top 3 rows

# %%
df.show(3, 3)
# Out:
# +----+---+----+
# |name|age|city|
# +----+---+----+
# | Ali| 25| New|
# | Bob| 30| San|
# | Bob| 12| Las|
# +----+---+----+
# only showing top 3 rows

# %%
df.show(3, 3, True)
# Out:
# -RECORD 0---
#  name | Ali
#  age  | 25
#  city | New
# -RECORD 1---
#  name | Bob
#  age  | 30
#  city | San
# -RECORD 2---
#  name | Bob
#  age  | 12
#  city | Las
# only showing top 3 rows

# %%
df.show(vertical=True)
# Out:
# -RECORD 0-------------
#  name | Alice
#  age  | 25
#  city | New York
# -RECORD 1-------------
#  name | Bob
#  age  | 30
#  city | San Francisco
# -RECORD 2-------------
#  name | Bob
#  age  | 12
#  city | Las Vegas
# -RECORD 3-------------
#  name | Charlie
#  age  | 35
#  city | Chicago
# -RECORD 4-------------
#  name | Charlie
#  age  | 35
#  city | Chicago

# %%
df.show(n=20, truncate=True, vertical=False)
# Out:
# +-------+---+-------------+
# |   name|age|         city|
# +-------+---+-------------+
# |  Alice| 25|     New York|
# |    Bob| 30|San Francisco|
# |    Bob| 12|    Las Vegas|
# |Charlie| 35|      Chicago|
# |Charlie| 35|      Chicago|
# +-------+---+-------------+

# %%
df.toPandas()
# Out:
#       name  age           city
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2      Bob   12      Las Vegas
# 3  Charlie   35        Chicago
# 4  Charlie   35        Chicago

# %%
df.count()
# Out:
# 5

# %%
df = df.select('name', 'age')

df.limit(1).show()
# Out:
# +-----+---+
# | name|age|
# +-----+---+
# |Alice| 25|
# +-----+---+

# %%
df.collect()
# Out:
# [Row(name='Alice', age=25),
#  Row(name='Bob', age=30),
#  Row(name='Bob', age=12),
#  Row(name='Charlie', age=35),
#  Row(name='Charlie', age=35)]

# %%
type(df.collect())
# Out:
# list

# %%
for row in df.collect():
    print(row['name'], row['age'])
# Out:
# Alice 25
# Bob 30
# Bob 12
# Charlie 35
# Charlie 35

# %%
df.take(2)
# Out:
# [Row(name='Alice', age=25), Row(name='Bob', age=30)]

# %%
df.head(2)
# Out:
# [Row(name='Alice', age=25), Row(name='Bob', age=30)]

# %%
df.first()
# Out:
# Row(name='Alice', age=25)

# %%
df.tail(2)
# Out:
# [Row(name='Charlie', age=35), Row(name='Charlie', age=35)]
