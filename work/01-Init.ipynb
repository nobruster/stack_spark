# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.sql import Window

# %%
spark = SparkSession.builder \
    .master("spark://spark-master:7077") \
    .appName("meu-app") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/25 03:23:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/25 03:23:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/02/25 03:23:48 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 26/02/25 03:23:48 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.

# %%
# Create SparkSession
spark = (SparkSession.builder
                    .appName('PySparkSyntax')
                    .config("spark.executor.memory", "4G")
                    .config("spark.driver.memory", "2G")
                    .getOrCreate()
        )

print(f'The PySpark {spark.version} version is running...')
# Out:
# The PySpark 3.5.5 version is running...
# 26/02/25 03:23:50 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://jupyter-1:4043">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>meu-app</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.conf.get("spark.executor.memory")
# Out:
# '4G'

# %%
spark.conf.get("spark.driver.memory")
# Out:
# '2G'

# %%
spark.conf.get("spark.sql.shuffle.partitions")
# Out:
# '200'

# %%
spark.conf.set("spark.sql.shuffle.partitions", "100")

# %%
spark.conf.get("spark.sql.shuffle.partitions")
# Out:
# '100'

# %%
spark.stop()
